# %% [markdown]
# # Test to apply Cadet-process
#
# ## General information
#
# - The code displayed below is the exmple from the Cadet process documentation from the [process simulation](https://cadet-process.readthedocs.io/en/latest/getting_started/reactions.html).
# - I installed the Cadet version via conda and the cadet process as described in this [cadet forum thread](https://forum.cadet-web.de/t/cadet-process-parameter-estimation/524/9)
# -  My system is running on windows 10 and the Jupyter notebook is running in a new conda env with the following dependencies:
#
# <details><Summary>Conda packages</Summary>
#
# ```bash
# # Name                    Version                   Build  Channel
# about-time                4.2.1                    pypi_0    pypi
# addict                    2.4.0                    pypi_0    pypi
# alive-progress            3.0.1                    pypi_0    pypi
# anyio                     3.6.2                    pypi_0    pypi
# appdirs                   1.4.4                    pypi_0    pypi
# arviz                     0.15.0                   pypi_0    pypi
# asttokens                 2.2.1              pyhd8ed1ab_0    conda-forge
# autograd                  1.5                      pypi_0    pypi
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                pyhd8ed1ab_3    conda-forge
# backports.functools_lru_cache 1.6.4              pyhd8ed1ab_0    conda-forge
# bzip2                     1.0.8                he774522_0
# ca-certificates           2022.12.7            h5b45459_0    conda-forge
# cadet                     4.3.0                hbe8a693_3    conda-forge
# cadet-process             0.6.3                    pypi_0    pypi
# cadet-python              0.14                     pypi_0    pypi
# certifi                   2022.12.7          pyhd8ed1ab_0    conda-forge
# cma                       3.2.2                    pypi_0    pypi
# cobra                     0.26.2                   pypi_0    pypi
# colorama                  0.4.6              pyhd8ed1ab_0    conda-forge
# contourpy                 1.0.7                    pypi_0    pypi
# corner                    2.2.1                    pypi_0    pypi
# cycler                    0.11.0                   pypi_0    pypi
# debugpy                   1.5.1           py310hd77b12b_0
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# depinfo                   1.7.0                    pypi_0    pypi
# deprecated                1.2.13                   pypi_0    pypi
# dill                      0.3.6                    pypi_0    pypi
# diskcache                 5.4.0                    pypi_0    pypi
# executing                 1.2.0              pyhd8ed1ab_0    conda-forge
# filelock                  3.9.0                    pypi_0    pypi
# fonttools                 4.38.0                   pypi_0    pypi
# future                    0.18.3                   pypi_0    pypi
# grapheme                  0.6.0                    pypi_0    pypi
# h11                       0.14.0                   pypi_0    pypi
# h5netcdf                  1.1.0                    pypi_0    pypi
# h5py                      3.6.0                    pypi_0    pypi
# hdf5                      1.12.1               h1756f20_2
# hopsy                     1.1.0                    pypi_0    pypi
# httpcore                  0.16.3                   pypi_0    pypi
# httpx                     0.23.3                   pypi_0    pypi
# icc_rt                    2022.1.0             h6049295_2
# idna                      3.4                      pypi_0    pypi
# importlib-metadata        6.0.0              pyha770c72_0    conda-forge
# importlib-resources       5.12.0                   pypi_0    pypi
# importlib_metadata        6.0.0                hd8ed1ab_0    conda-forge
# intel-openmp              2023.0.0         h57928b3_25922    conda-forge
# ipykernel                 6.15.0             pyh025b116_0    conda-forge
# ipython                   8.11.0             pyh08f2357_0    conda-forge
# jedi                      0.18.2             pyhd8ed1ab_0    conda-forge
# joblib                    1.2.0                    pypi_0    pypi
# jupyter_client            8.0.3              pyhd8ed1ab_0    conda-forge
# jupyter_core              5.2.0           py310h5588dad_0    conda-forge
# kiwisolver                1.4.4                    pypi_0    pypi
# libblas                   3.9.0              16_win64_mkl    conda-forge
# libcblas                  3.9.0              16_win64_mkl    conda-forge
# libffi                    3.4.2                hd77b12b_6
# liblapack                 3.9.0              16_win64_mkl    conda-forge
# liblapacke                3.9.0              16_win64_mkl    conda-forge
# libsodium                 1.0.18               h8d14728_1    conda-forge
# llvmlite                  0.39.1                   pypi_0    pypi
# markdown-it-py            2.2.0                    pypi_0    pypi
# matplotlib                3.7.0                    pypi_0    pypi
# matplotlib-inline         0.1.6              pyhd8ed1ab_0    conda-forge
# mdurl                     0.1.2                    pypi_0    pypi
# mkl                       2022.1.0           h6a75c08_874    conda-forge
# mpmath                    1.2.1                    pypi_0    pypi
# multiprocess              0.70.14                  pypi_0    pypi
# nest-asyncio              1.5.6              pyhd8ed1ab_0    conda-forge
# numba                     0.56.4                   pypi_0    pypi
# numpy                     1.23.5                   pypi_0    pypi
# openssl                   1.1.1t               h2bbff1b_0
# optlang                   1.6.1                    pypi_0    pypi
# packaging                 23.0               pyhd8ed1ab_0    conda-forge
# pandas                    1.5.3                    pypi_0    pypi
# parso                     0.8.3              pyhd8ed1ab_0    conda-forge
# pathos                    0.3.0                    pypi_0    pypi
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    9.4.0                    pypi_0    pypi
# pip                       22.3.1          py310haa95532_0
# platformdirs              3.0.0              pyhd8ed1ab_0    conda-forge
# polyround                 0.2.5                    pypi_0    pypi
# pox                       0.3.2                    pypi_0    pypi
# ppft                      1.7.6.6                  pypi_0    pypi
# prompt-toolkit            3.0.38             pyha770c72_0    conda-forge
# prompt_toolkit            3.0.38               hd8ed1ab_0    conda-forge
# psutil                    5.9.0           py310h2bbff1b_0
# pure_eval                 0.2.2              pyhd8ed1ab_0    conda-forge
# pydantic                  1.10.5                   pypi_0    pypi
# pygments                  2.14.0             pyhd8ed1ab_0    conda-forge
# pymoo                     0.6.0.1                  pypi_0    pypi
# pyparsing                 3.0.9                    pypi_0    pypi
# python                    3.10.9               h966fe2a_0
# python-dateutil           2.8.2              pyhd8ed1ab_0    conda-forge
# python-libsbml            5.19.7                   pypi_0    pypi
# python_abi                3.10                    2_cp310    conda-forge
# pytz                      2022.7.1                 pypi_0    pypi
# pywin32                   305             py310h2bbff1b_0
# pyzmq                     23.2.0          py310hd77b12b_0
# rfc3986                   1.5.0                    pypi_0    pypi
# rich                      13.3.1                   pypi_0    pypi
# ruamel-yaml               0.17.21                  pypi_0    pypi
# ruamel-yaml-clib          0.2.7                    pypi_0    pypi
# scikit-learn              1.2.1                    pypi_0    pypi
# scipy                     1.10.1                   pypi_0    pypi
# setuptools                65.6.3          py310haa95532_0
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# sniffio                   1.3.0                    pypi_0    pypi
# sqlite                    3.40.1               h2bbff1b_0
# stack_data                0.6.2              pyhd8ed1ab_0    conda-forge
# suitesparse               5.4.0                h5d0cbe0_1    conda-forge
# swiglpk                   5.0.8                    pypi_0    pypi
# sympy                     1.11.1                   pypi_0    pypi
# tbb                       2021.7.0             h59b6b97_0
# tbb-devel                 2021.7.0             h59b6b97_0
# threadpoolctl             3.1.0                    pypi_0    pypi
# tk                        8.6.12               h2bbff1b_0
# tornado                   6.2             py310he2412df_0    conda-forge
# tqdm                      4.64.1                   pypi_0    pypi
# traitlets                 5.9.0              pyhd8ed1ab_0    conda-forge
# typing-extensions         4.5.0                    pypi_0    pypi
# typing_extensions         4.4.0              pyha770c72_0    conda-forge
# tzdata                    2022g                h04d1e81_0
# vc                        14.2                 h21ff451_1
# vs2015_runtime            14.27.29016          h5e58377_2
# wcwidth                   0.2.6              pyhd8ed1ab_0    conda-forge
# wheel                     0.38.4          py310haa95532_0
# wincertstore              0.2             py310haa95532_2
# wrapt                     1.15.0                   pypi_0    pypi
# xarray                    2023.2.0                 pypi_0    pypi
# xarray-einstats           0.5.1                    pypi_0    pypi
# xz                        5.2.10               h8cc25b3_1
# zeromq                    4.3.4                h0e60522_1    conda-forge
# zipp                      3.15.0             pyhd8ed1ab_0    conda-forge
# zlib                      1.2.13               h8cc25b3_0
#
# ```
#
# </details>
#
# <details><Summary>pip packages</Summary>
#
# ```bash
#
# Package                       Version
# ----------------------------- ---------
# about-time                    4.2.1
# addict                        2.4.0
# alive-progress                3.0.1
# anyio                         3.6.2
# appdirs                       1.4.4
# arviz                         0.15.0
# asttokens                     2.2.1
# autograd                      1.5
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# CADET-Process                 0.6.3
# CADET-Python                  0.14
# certifi                       2022.12.7
# cma                           3.2.2
# cobra                         0.26.2
# colorama                      0.4.6
# contourpy                     1.0.7
# corner                        2.2.1
# cycler                        0.11.0
# debugpy                       1.5.1
# decorator                     5.1.1
# depinfo                       1.7.0
# Deprecated                    1.2.13
# dill                          0.3.6
# diskcache                     5.4.0
# executing                     1.2.0
# filelock                      3.9.0
# fonttools                     4.38.0
# future                        0.18.3
# grapheme                      0.6.0
# h11                           0.14.0
# h5netcdf                      1.1.0
# h5py                          3.6.0
# hopsy                         1.1.0
# httpcore                      0.16.3
# httpx                         0.23.3
# idna                          3.4
# importlib-metadata            6.0.0
# importlib-resources           5.12.0
# ipykernel                     6.15.0
# ipython                       8.11.0
# jedi                          0.18.2
# joblib                        1.2.0
# jupyter_client                8.0.3
# jupyter_core                  5.2.0
# kiwisolver                    1.4.4
# llvmlite                      0.39.1
# markdown-it-py                2.2.0
# matplotlib                    3.7.0
# matplotlib-inline             0.1.6
# mdurl                         0.1.2
# mpmath                        1.2.1
# multiprocess                  0.70.14
# nest-asyncio                  1.5.6
# numba                         0.56.4
# numpy                         1.23.5
# optlang                       1.6.1
# packaging                     23.0
# pandas                        1.5.3
# parso                         0.8.3
# pathos                        0.3.0
# pickleshare                   0.7.5
# Pillow                        9.4.0
# pip                           22.3.1
# platformdirs                  3.0.0
# PolyRound                     0.2.5
# pox                           0.3.2
# ppft                          1.7.6.6
# prompt-toolkit                3.0.38
# psutil                        5.9.0
# pure-eval                     0.2.2
# pydantic                      1.10.5
# Pygments                      2.14.0
# pymoo                         0.6.0.1
# pyparsing                     3.0.9
# python-dateutil               2.8.2
# python-libsbml                5.19.7
# pytz                          2022.7.1
# pywin32                       305.1
# pyzmq                         23.2.0
# rfc3986                       1.5.0
# rich                          13.3.1
# ruamel.yaml                   0.17.21
# ruamel.yaml.clib              0.2.7
# scikit-learn                  1.2.1
# scipy                         1.10.1
# setuptools                    65.6.3
# six                           1.16.0
# sniffio                       1.3.0
# stack-data                    0.6.2
# swiglpk                       5.0.8
# sympy                         1.11.1
# threadpoolctl                 3.1.0
# tornado                       6.2
# tqdm                          4.64.1
# traitlets                     5.9.0
# typing_extensions             4.5.0
# wcwidth                       0.2.6
# wheel                         0.38.4
# wincertstore                  0.2
# wrapt                         1.15.0
# xarray                        2023.2.0
# xarray-einstats               0.5.1
# zipp                          3.15.0
#
# ```
#
# </details>
#
# ## Problems
#
# - At the moment I have two problems:
# - 1. When I run the example I cannot set the volume of the reactor (`AttributeError: can't set attribute 'volume'`) (see below)
# - 2. When I leave out the volume and run a test simulation it takes more than 45 min and is still not finished. I haven't managed to run a successful test simulation yet

# %%
from CADETProcess.processModel import ComponentSystem
component_system = ComponentSystem(['A', 'B', 'C', 'D'])

# %%
from CADETProcess.processModel import MassActionLaw
reaction_system = MassActionLaw(component_system) 
reaction_system.add_reaction(
    indices=[0,1], 
    coefficients=[-1, 1],
    k_fwd=0.1,
    k_bwd=0.05,
)

reaction_system.add_reaction(
    indices=[1,2], 
    coefficients=[-1, 1],
    k_fwd=0.5,
    k_bwd=0,
)

# %%
print(reaction_system.reactions[1])
# Out:
# B <=>[5.00E-01][0.00E+00] C

# %%
from CADETProcess.processModel import Cstr
reactor = Cstr(component_system, 'reactor')
reactor.V = 1e-6
reactor.bulk_reaction_model = reaction_system
reactor.c = [15.0, 0.0, 0.0, 0.0]

# %%
from CADETProcess.processModel import FlowSheet
flow_sheet = FlowSheet(component_system)
flow_sheet.add_unit(reactor)

from CADETProcess.processModel import Process
process = Process(flow_sheet, 'reaction_demo')
process.cycle_time = 100

# %%
from CADETProcess.simulator import Cadet
simulator = Cadet()
#sim_results = simulator.run(process)
sim_results = simulator.simulate(process)
print(dir(sim_results.solution.reactor.outlet))
print(sim_results.solution.reactor.outlet.solution)
_ = sim_results.solution.reactor.outlet.plot()
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '